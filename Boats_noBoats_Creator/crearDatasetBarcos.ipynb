# %%
import os
import cv2
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm
import shutil

# --- CONFIGURACIÓN ---
# Rutas del modelo y el dataset
YOLO5_REPO_PATH = 'yolov5'
MODEL_PATH = 'best.pt'
DATASET_BASE_PATH = 'yolo_dataset'
TEST_SUBSET_NAME = 'val'  # Usaremos el conjunto 'val' como nuestro conjunto de test

# Parámetros del análisis
IOU_THRESHOLD = 0.1
NUM_IMAGES_TO_TEST = 5000  # Número de imágenes a procesar

# Nombres de las carpetas de salida
OUTPUT_DIR_BARCOS = 'barcos'
OUTPUT_DIR_ERRORES = 'misclassifications'

# --- FUNCIONES DE AYUDA ---

def calculate_iou(boxA, boxB):
    """Calcula la Intersección sobre Unión (IoU) entre dos recuadros [xmin, ymin, xmax, ymax]."""
    interArea = max(0, min(boxA[2], boxB[2]) - max(boxA[0], boxB[0])) * max(0, min(boxA[3], boxB[3]) - max(boxA[1], boxB[1]))
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    unionArea = float(boxAArea + boxBArea - interArea)
    return interArea / unionArea if unionArea > 0 else 0

def load_ground_truth_boxes(annotation_path, img_width, img_height):
    """Carga los recuadros desde un archivo .txt de YOLO y los desnormaliza."""
    boxes = []
    if not os.path.exists(annotation_path): return boxes
    with open(annotation_path, 'r') as f:
        for line in f:
            _, x_center, y_center, width, height = map(float, line.strip().split())
            w_abs, h_abs = width * img_width, height * img_height
            xmin = (x_center * img_width) - (w_abs / 2)
            ymin = (y_center * img_height) - (h_abs / 2)
            xmax = xmin + w_abs
            ymax = ymin + h_abs
            boxes.append([xmin, ymin, xmax, ymax])
    return boxes

# --- FUNCIÓN PRINCIPAL DEL SCRIPT ---

def main():
    """
    Función principal que carga el modelo, procesa las imágenes y guarda los recortes sin mostrar ninguna GUI.
    """
    # --- 1. Cargar el modelo ---
    print("Cargando el modelo YOLOv5...")
    model = torch.hub.load(YOLO5_REPO_PATH, 'custom', path=MODEL_PATH, source='local', force_reload=True)
    if torch.cuda.is_available():
        model.to('cuda')
        print("Modelo cargado en la GPU.")
    else:
        print("Modelo cargado en la CPU.")

    # --- 2. Preparar carpetas de salida ---
    print(f"Creando/limpiando carpetas de salida: '{OUTPUT_DIR_BARCOS}' y '{OUTPUT_DIR_ERRORES}'")
    for dir_path in [OUTPUT_DIR_BARCOS, OUTPUT_DIR_ERRORES]:
        if os.path.exists(dir_path):
            shutil.rmtree(dir_path)
        os.makedirs(dir_path)

    # --- 3. Obtener la lista de imágenes a procesar ---
    images_path = os.path.join(DATASET_BASE_PATH, TEST_SUBSET_NAME, 'images')
    labels_path = os.path.join(DATASET_BASE_PATH, TEST_SUBSET_NAME, 'labels')
    if not os.path.exists(images_path):
        print(f"❌ Error fatal: No se encuentra el directorio de imágenes en '{images_path}'")
        return
    test_images = sorted(os.listdir(images_path))[:NUM_IMAGES_TO_TEST]
    print(f"Se procesarán las primeras {len(test_images)} imágenes de '{images_path}'")

    # --- 4. Bucle principal de procesamiento ---
    for image_name in tqdm(test_images, desc="Procesando imágenes"):
        image_path = os.path.join(images_path, image_name)
        label_path = os.path.join(labels_path, os.path.splitext(image_name)[0] + '.txt')

        original_image = cv2.imread(image_path)
        if original_image is None: continue
        
        img_height, img_width, _ = original_image.shape
        gt_boxes = load_ground_truth_boxes(label_path, img_width, img_height)

        img_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
        results = model(img_rgb)
        pred_df = results.pandas().xyxy[0]
        pred_boxes = pred_df[['xmin', 'ymin', 'xmax', 'ymax']].values.tolist()

        # --- Lógica de matching y guardado de archivos ---
        gt_boxes_matched = [False] * len(gt_boxes)
        base_filename = os.path.splitext(image_name)[0]

        # Procesar predicciones (TP y FP)
        for i, pred_box in enumerate(pred_boxes):
            xmin, ymin, xmax, ymax = map(int, pred_box)
            crop_img = original_image[ymin:ymax, xmin:xmax]
            if crop_img.size == 0: continue

            best_iou, best_gt_idx = 0, -1
            for j, gt_box in enumerate(gt_boxes):
                iou = calculate_iou(pred_box, gt_box)
                if iou > best_iou: best_iou, best_gt_idx = iou, j
            
            if best_iou > IOU_THRESHOLD and best_gt_idx != -1 and not gt_boxes_matched[best_gt_idx]:
                # VERDADERO POSITIVO (TP)
                save_path = os.path.join(OUTPUT_DIR_BARCOS, f"{base_filename}_tp_{i}.png")
                cv2.imwrite(save_path, crop_img)
                gt_boxes_matched[best_gt_idx] = True
            else:
                # FALSO POSITIVO (FP)
                save_path = os.path.join(OUTPUT_DIR_ERRORES, f"{base_filename}_fp_{i}.png")
                cv2.imwrite(save_path, crop_img)

        # Procesar verdad terrenal no detectada (FN)
        for i, matched in enumerate(gt_boxes_matched):
            if not matched:
                xmin, ymin, xmax, ymax = map(int, gt_boxes[i])
                crop_img = original_image[ymin:ymax, xmin:xmax]
                if crop_img.size == 0: continue
                
                save_path = os.path.join(OUTPUT_DIR_BARCOS, f"{base_filename}_fn_{i}.png")
                cv2.imwrite(save_path, crop_img)
    
    # --- 5. Finalización ---
    print("\n¡Proceso completado!")
    print(f"Los recortes de los barcos se han guardado en la carpeta '{OUTPUT_DIR_BARCOS}'.")
    print(f"Los recortes de las detecciones incorrectas se han guardado en la carpeta '{OUTPUT_DIR_ERRORES}'.")


# --- Punto de entrada del script ---
if __name__ == "__main__":
    main()
# Out:
# Cargando el modelo YOLOv5...
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\utils\general.py:32: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources as pkg
# YOLOv5  v7.0-422-g2540fd4c Python-3.13.1 torch-2.7.1+cpu CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...
# Modelo cargado en la CPU.
# Creando/limpiando carpetas de salida: 'barcos' y 'misclassifications'
# Se procesarán las primeras 1962 imágenes de 'yolo_dataset\val\images'
# Procesando imágenes:   0%|          | 0/1962 [00:00<?, ?it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 1/1962 [00:00<23:05,  1.42it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 2/1962 [00:01<15:34,  2.10it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 3/1962 [00:01<12:34,  2.60it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 4/1962 [00:01<10:55,  2.98it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 5/1962 [00:01<09:59,  3.26it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 6/1962 [00:02<09:33,  3.41it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 7/1962 [00:02<09:17,  3.50it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 8/1962 [00:02<10:13,  3.19it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   0%|          | 9/1962 [00:03<09:54,  3.28it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 10/1962 [00:03<09:23,  3.47it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 11/1962 [00:03<09:16,  3.50it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 12/1962 [00:03<08:55,  3.64it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 13/1962 [00:04<08:38,  3.76it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 14/1962 [00:04<08:10,  3.97it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 15/1962 [00:04<08:11,  3.96it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 16/1962 [00:04<08:00,  4.05it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 17/1962 [00:04<08:03,  4.02it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 18/1962 [00:05<07:59,  4.05it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 19/1962 [00:05<08:12,  3.95it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 20/1962 [00:05<09:04,  3.57it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 21/1962 [00:06<09:56,  3.25it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 22/1962 [00:06<10:41,  3.02it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 23/1962 [00:07<11:54,  2.71it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|          | 24/1962 [00:07<10:01,  3.22it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|▏         | 25/1962 [00:07<08:03,  4.01it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|▏         | 26/1962 [00:07<06:37,  4.87it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|▏         | 27/1962 [00:07<05:49,  5.54it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   1%|▏         | 29/1962 [00:07<04:43,  6.82it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 30/1962 [00:07<04:20,  7.41it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 32/1962 [00:08<03:51,  8.34it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 33/1962 [00:08<03:43,  8.62it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 34/1962 [00:08<03:46,  8.51it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 35/1962 [00:08<03:43,  8.63it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 36/1962 [00:08<03:42,  8.65it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 37/1962 [00:08<03:36,  8.90it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 38/1962 [00:08<03:40,  8.72it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 39/1962 [00:08<03:44,  8.56it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 40/1962 [00:08<03:39,  8.77it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 41/1962 [00:09<03:40,  8.73it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 42/1962 [00:09<03:41,  8.66it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 43/1962 [00:09<04:09,  7.68it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 44/1962 [00:09<04:09,  7.69it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 45/1962 [00:09<04:18,  7.41it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 46/1962 [00:09<04:21,  7.32it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 47/1962 [00:09<04:44,  6.73it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 48/1962 [00:10<04:21,  7.31it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   2%|▏         | 49/1962 [00:10<04:10,  7.64it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 50/1962 [00:10<04:10,  7.63it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 51/1962 [00:10<04:00,  7.93it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 52/1962 [00:10<03:51,  8.25it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 53/1962 [00:10<04:01,  7.89it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 54/1962 [00:10<04:28,  7.11it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 55/1962 [00:10<04:10,  7.60it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 56/1962 [00:11<04:04,  7.80it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 57/1962 [00:11<03:55,  8.10it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 58/1962 [00:11<03:48,  8.33it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 59/1962 [00:11<03:41,  8.61it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 60/1962 [00:11<03:35,  8.83it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 62/1962 [00:11<03:25,  9.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 63/1962 [00:11<03:23,  9.32it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 65/1962 [00:12<03:22,  9.38it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 66/1962 [00:12<03:35,  8.78it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 67/1962 [00:12<03:53,  8.11it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   3%|▎         | 68/1962 [00:12<04:34,  6.90it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▎         | 69/1962 [00:12<05:46,  5.47it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▎         | 70/1962 [00:13<05:59,  5.26it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▎         | 71/1962 [00:13<05:22,  5.87it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▎         | 72/1962 [00:13<04:51,  6.49it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▎         | 73/1962 [00:13<04:27,  7.05it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 74/1962 [00:13<04:16,  7.36it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 75/1962 [00:13<04:15,  7.38it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 76/1962 [00:13<03:58,  7.89it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 77/1962 [00:13<04:21,  7.21it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 78/1962 [00:14<04:06,  7.63it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 79/1962 [00:14<04:04,  7.71it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 80/1962 [00:14<03:55,  7.99it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 81/1962 [00:14<03:55,  7.98it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 82/1962 [00:14<03:48,  8.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 83/1962 [00:14<03:41,  8.49it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 84/1962 [00:14<03:40,  8.51it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 85/1962 [00:14<03:34,  8.77it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 86/1962 [00:14<03:34,  8.76it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 87/1962 [00:15<03:30,  8.91it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   4%|▍         | 88/1962 [00:15<03:45,  8.30it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 89/1962 [00:15<03:41,  8.45it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 90/1962 [00:15<04:10,  7.47it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 91/1962 [00:15<04:13,  7.39it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 92/1962 [00:15<04:14,  7.34it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 93/1962 [00:15<04:05,  7.62it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 94/1962 [00:16<04:02,  7.71it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 95/1962 [00:16<03:54,  7.97it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 96/1962 [00:16<04:14,  7.32it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 97/1962 [00:16<03:59,  7.80it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▍         | 98/1962 [00:16<04:00,  7.76it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 100/1962 [00:16<03:36,  8.60it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 101/1962 [00:16<03:32,  8.77it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 102/1962 [00:16<03:30,  8.85it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 103/1962 [00:17<04:08,  7.49it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 104/1962 [00:17<05:08,  6.03it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 105/1962 [00:17<06:00,  5.15it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 106/1962 [00:17<06:41,  4.62it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   5%|▌         | 107/1962 [00:18<07:43,  4.00it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 108/1962 [00:18<08:05,  3.82it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 109/1962 [00:18<08:21,  3.69it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 110/1962 [00:19<08:14,  3.75it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 111/1962 [00:19<09:29,  3.25it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 112/1962 [00:19<09:17,  3.32it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 113/1962 [00:20<08:42,  3.54it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 114/1962 [00:20<08:09,  3.77it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 115/1962 [00:20<07:56,  3.88it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 116/1962 [00:20<07:47,  3.95it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 117/1962 [00:21<08:20,  3.69it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 118/1962 [00:21<08:43,  3.52it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 119/1962 [00:21<08:53,  3.45it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 120/1962 [00:21<08:37,  3.56it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 121/1962 [00:22<08:17,  3.70it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▌         | 122/1962 [00:22<08:00,  3.83it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▋         | 123/1962 [00:22<07:45,  3.95it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▋         | 124/1962 [00:22<08:01,  3.82it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▋         | 125/1962 [00:23<07:47,  3.93it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▋         | 126/1962 [00:23<07:47,  3.93it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   6%|▋         | 127/1962 [00:23<07:31,  4.06it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 128/1962 [00:23<07:44,  3.95it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 129/1962 [00:24<09:08,  3.34it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 130/1962 [00:24<09:02,  3.38it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 131/1962 [00:24<09:02,  3.38it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 132/1962 [00:25<09:03,  3.37it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 133/1962 [00:25<10:00,  3.05it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 134/1962 [00:25<09:24,  3.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 135/1962 [00:26<09:24,  3.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 136/1962 [00:26<09:12,  3.31it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 137/1962 [00:26<08:38,  3.52it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 138/1962 [00:26<08:13,  3.70it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:   7%|▋         | 139/1962 [00:27<08:07,  3.74it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1916/1962 [10:34<00:18,  2.43it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1917/1962 [10:34<00:17,  2.58it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1918/1962 [10:35<00:17,  2.47it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1919/1962 [10:35<00:19,  2.22it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1920/1962 [10:36<00:17,  2.36it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1921/1962 [10:36<00:22,  1.83it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1922/1962 [10:37<00:19,  2.08it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1923/1962 [10:37<00:18,  2.13it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1924/1962 [10:38<00:16,  2.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1925/1962 [10:38<00:15,  2.46it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1926/1962 [10:39<00:23,  1.52it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1927/1962 [10:40<00:19,  1.75it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1928/1962 [10:40<00:18,  1.84it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1929/1962 [10:40<00:15,  2.13it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1930/1962 [10:41<00:14,  2.16it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1931/1962 [10:41<00:12,  2.43it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  98%|█████████▊| 1932/1962 [10:41<00:11,  2.63it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▊| 1933/1962 [10:42<00:12,  2.28it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▊| 1934/1962 [10:42<00:10,  2.57it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▊| 1935/1962 [10:43<00:09,  2.72it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▊| 1936/1962 [10:43<00:09,  2.60it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▊| 1937/1962 [10:43<00:09,  2.59it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1938/1962 [10:44<00:10,  2.21it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1939/1962 [10:44<00:10,  2.25it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1940/1962 [10:45<00:08,  2.54it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1941/1962 [10:45<00:07,  2.68it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1942/1962 [10:46<00:08,  2.36it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1943/1962 [10:46<00:07,  2.48it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1944/1962 [10:46<00:07,  2.43it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1945/1962 [10:47<00:06,  2.52it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1946/1962 [10:47<00:05,  2.69it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1947/1962 [10:47<00:05,  2.76it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1948/1962 [10:48<00:06,  2.24it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1949/1962 [10:48<00:05,  2.55it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1950/1962 [10:49<00:04,  2.55it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1951/1962 [10:49<00:04,  2.65it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes:  99%|█████████▉| 1952/1962 [10:49<00:03,  2.93it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1953/1962 [10:50<00:02,  3.14it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1954/1962 [10:50<00:03,  2.64it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1955/1962 [10:50<00:02,  2.78it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1956/1962 [10:51<00:01,  3.02it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1957/1962 [10:51<00:01,  2.56it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1958/1962 [10:51<00:01,  2.71it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1959/1962 [10:52<00:01,  2.96it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1960/1962 [10:52<00:00,  2.54it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|█████████▉| 1961/1962 [10:53<00:00,  2.65it/s]c:\Users\angel\Desktop\Carpetas\SpaceChallenges\project\HRSID_JPG\PruebaClasificacion\yolov5\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Procesando imágenes: 100%|██████████| 1962/1962 [10:53<00:00,  3.00it/s]
# ¡Proceso completado!
# Los recortes de los barcos se han guardado en la carpeta 'barcos'.
# Los recortes de las detecciones incorrectas se han guardado en la carpeta 'misclassifications'.
